# %% [markdown]
# # 데이터 시각화 Plotting 기능 활용하기
# * 막대 그래프(-graph), 바 차트(bar chart), 바 그래프(bar graph)는 표현 값에 비례하여 높이와 길이를 지닌 직사각형 막대로 범주형 데이터를 표현하는 차트나 그래프를 말한다. 막대는 수직으로나 수평으로 그릴 수 있다. 수직 막대 그래프는 선 그래프 또는 라인 그래프(line graph)라고도 한다. (출처 : [막대 그래프 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%A7%89%EB%8C%80_%EA%B7%B8%EB%9E%98%ED%94%84))
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# <br><br>
# - df.plot.hist()
# - df.plot.scatter(x = 'w', y = 'h')

# %% [markdown]
# ## 17강) 파이썬 판다스로 Series와 DataFrame데이터 시각화 하기 소개

# %%
import pandas as pd
import numpy as np

# matplotlib의 plotting기능을 사용하기 위해 부름
import matplotlib.pyplot as plt
import matplotlib as mpl

# 쥬피터 노트북상에서 그래프를 그리게 하는 코드
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df.plot?

# %% [markdown]
# ## plot
# ### kind : str
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot (bar의 x,y축을 서로 바꿔줌)
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot

# %%
# numpy를 통한 랜덤한 숫자 사용을 한다.
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01    1.945181
# 2000-01-02   -0.602295
# 2000-01-03   -0.940169
# 2000-01-04    0.315400
# 2000-01-05   -0.250329
# 2000-01-06   -1.413047
# 2000-01-07   -2.084362
# 2000-01-08   -0.237087
# 2000-01-09   -0.472525
# 2000-01-10    1.369859
# 2000-01-11    1.763392
# 2000-01-12   -2.005022
# 2000-01-13    0.120722
# 2000-01-14   -0.453255
# 2000-01-15   -0.078561
# 2000-01-16    1.499740
# 2000-01-17    0.246924
# 2000-01-18   -1.040780
# 2000-01-19    1.032022
# 2000-01-20    0.347887
# 2000-01-21   -0.653050
# 2000-01-22   -1.488513
# 2000-01-23    1.064887
# 2000-01-24    0.954412
# 2000-01-25   -1.671485
# 2000-01-26    1.402109
# 2000-01-27    1.001401
# 2000-01-28    1.030173
# 2000-01-29    1.017151
# 2000-01-30    0.718675
#                 ...
# 2002-08-28    0.576445
# 2002-08-29   -0.693791
# 2002-08-30    1.535140
# 2002-08-31   -0.691113
# 2002-09-01   -0.439025
# 2002-09-02   -2.572530
# 2002-09-03    2.203730
# 2002-09-04   -0.378736
# 2002-09-05   -0.985923
# ...

# %%
ts.plot()

# %%
# 누적합 구하기
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.581877 -1.470597 -0.060546 -1.167909
# 2000-01-02 -1.100770 -0.879133  0.505992 -0.707655
# 2000-01-03 -0.272988  0.212046 -0.343282  2.430695
# 2000-01-04 -0.390006 -0.043178  0.112080  0.747905
# 2000-01-05 -0.116586 -0.636279 -2.044073  0.749965
# 2000-01-06  0.668939  0.804129 -0.113001 -0.613328
# 2000-01-07 -1.129239  0.366678  0.005254 -0.962758
# 2000-01-08  0.986515 -1.234801 -0.364521  0.193010
# 2000-01-09 -0.281280  1.730512  0.351693 -1.030778
# 2000-01-10  1.209395 -0.689904 -0.478106 -1.751212
# 2000-01-11 -0.602008  2.043128  0.587817  2.131422
# 2000-01-12  1.946258  1.509677 -1.591636 -0.462021
# 2000-01-13 -0.091805 -0.494367 -0.320176 -1.114747
# 2000-01-14 -0.189509 -0.753947 -1.142041 -1.194207
# 2000-01-15  1.369125 -1.409820 -0.053452 -0.186892
# 2000-01-16 -0.854410 -0.966724  0.053617  1.259228
# 2000-01-17 -1.079789  0.507217  0.068893  0.186884
# ...

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.plot()

# %%
# 누적합
df = df.cumsum()
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3.head()
# Out:
#           B         C
# 0 -1.276660  0.242470
# 1  0.164570 -0.127592
# 2 -0.105261 -0.410528
# 3  1.379783  0.800102
# 4  2.729546  0.134709

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0 -1.276660  0.242470  0
# 1  0.164570 -0.127592  1
# 2 -0.105261 -0.410528  2
# 3  1.379783  0.800102  3
# 4  2.729546  0.134709  4

# %%
# x축에는 A컬럼의 데이터를, y축에는 B컬럼의 데이터를 넣었다.
df3.plot(x = 'A', y = 'B')

# %% [markdown]
# ## 18강) 파이썬 데이터 시각화 판다스로 bar plot 막대 그래프 그리기
# - 판다스의 플로팅 기능이 matplotlib의 플로팅보다 사용이 편리하다
# - 따라서 별도의 시각화 라이브러리가 아닌 판다스의 시각화 라이브러리만 사용하여 플로팅한다

# %%
df.iloc[5]
# Out:
# A   -10.821309
# B   -12.969025
# C    -3.071350
# D     2.307370
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind = 'bar')

# %%
# 위의 코드를 이렇게도 가능하다.
df.iloc[5].plot.bar()
plt.axhline(0, color = 'k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2
# Out:
#           a         b         c         d
# 0  0.371543  0.607069  0.151842  0.893180
# 1  0.919422  0.064530  0.539987  0.310841
# 2  0.894438  0.515107  0.919755  0.391226
# 3  0.734615  0.398528  0.608830  0.354183
# 4  0.406840  0.995337  0.834486  0.963924
# 5  0.544396  0.733221  0.752741  0.263658
# 6  0.286179  0.602197  0.478138  0.614253
# 7  0.429563  0.203904  0.013493  0.993733
# 8  0.710718  0.818465  0.946053  0.872733
# 9  0.787910  0.576684  0.476413  0.944261

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.barh(stacked = True)

# %% [markdown]
# ## 19강) 파이썬 데이터 시각화 히스토그램과 도수분포표 이해하기, <br> 막대 그래프 vs 히스토그램 차이점 이해하기

# %% [markdown]
# ## Histograms
# ### 도수분포표 vs 히스토그램
# * 도수분포표 : 특정 구간에 속하는 자료의 개수를 표현 ([도수 분포 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%8F%84%EC%88%98_%EB%B6%84%ED%8F%AC))
# * 히스토그램 : 도수분포표를 시각화하여 막대그래프로 표현, 하지만 bar plot과는 다름 ([히스토그램 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%ED%9E%88%EC%8A%A4%ED%86%A0%EA%B7%B8%EB%9E%A8))
#
# ### 막대그래프 vs 히스토그램 (bar plot vs hist plot)
# * bar plot : 표현 값에 비례하여 높이와 길이를 지닌 직사각형 막대로 범주형 데이터를 표현하는 차트나 그래프, 합계, 평균 등의 수치를 시각화 ([막대 그래프 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%A7%89%EB%8C%80_%EA%B7%B8%EB%9E%98%ED%94%84))
# * hist plot : 구간별 빈도수를 표현 <br>
# => 막대그래프는 계급, 즉 가로를 생각하지 않고 세로의 높이로만 나타내지만 <br>
# 히스토그램은 가로와 세로를 함께 생각해야 한다.
#
# ### 히스토그램 vs 정규분포 (hist plot vs density plot)
# * hist plot : 구간별 빈도수
# * density plot : 확률 밀도 함수 - 확률 변수의 밀도를 표현 ([정규 분포 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%A0%95%EA%B7%9C_%EB%B6%84%ED%8F%AC))

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html  
# 위에서 가져온 데이터프레임
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1,
                    'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1},
                   columns=['a', 'b', 'c'])
df4.head()
# Out:
#           a         b         c
# 0  0.474032 -0.324913  0.222336
# 1  2.409133 -0.468514 -1.669852
# 2 -0.497507 -0.039691 -1.698474
# 3  1.848292  0.201393 -1.344464
# 4  0.188772 -0.098461 -2.077918

# %%
# alpha값은 투명도를 의미한다
df4.plot.hist(alpha = 0.45)

# 기본적으로 10개의 bin값이 있다.
# 구간에 해당하는 데이터가 몇개인가에 따라서 frequency개수를 히스토그램으로 표현하였다.

# %%
# stacked = True는 누적.
# 겹치는게 아니라 그 위에 계속 쌓아올리는 것
df4.plot.hist(stacked=True, bins=20)


# bin은 통에 담는 것을 의미한다. 
# bin값에 따라서 frequency값도 달라진다.

# %%
df4['a'].plot.hist(orientation='horizontal', cumulative=True)

# %% [markdown]
# ## 20강) 파이썬 판다스로 차분 diff값을 구하고 히스토그램으로 표한하기

# %%
df4['a'].diff().hist()

# %%
df4['a'].diff().head()
# Out:
# 0         NaN
# 1    1.935101
# 2   -2.906640
# 3    2.345799
# 4   -1.659520
# Name: a, dtype: float64

# %%
df4['a_diff'] = df4['a'].diff()
df4[['a', 'a_diff']]
# Out:
#             a    a_diff
# 0    0.474032       NaN
# 1    2.409133  1.935101
# 2   -0.497507 -2.906640
# 3    1.848292  2.345799
# 4    0.188772 -1.659520
# 5    2.508972  2.320200
# 6    0.545167 -1.963804
# 7    1.536209  0.991041
# 8    0.523482 -1.012727
# 9    1.420610  0.897128
# 10   1.094087 -0.326523
# 11   2.388095  1.294008
# 12  -0.382411 -2.770506
# 13  -1.603226 -1.220815
# 14   1.976352  3.579578
# 15   0.438746 -1.537606
# 16  -0.398706 -0.837453
# 17   1.888615  2.287321
# 18   2.466029  0.577415
# 19   0.408795 -2.057234
# 20   1.247554  0.838759
# 21   2.749943  1.502389
# 22   1.218518 -1.531425
# 23   1.018792 -0.199726
# 24   0.778131 -0.240660
# 25   1.401805  0.623674
# 26   0.907509 -0.494297
# 27  -0.051161 -0.958670
# 28   1.525934  1.577095
# 29   0.232115 -1.293819
# ..        ...       ...
# 970  1.460717  0.770566
# 971  0.136573 -1.324145
# 972  1.273795  1.137222
# 973  0.519004 -0.754791
# 974 -0.478026 -0.997029
# 975  0.931317  1.409343
# ...

# %%
df4['a_diff'] = df4['a'].diff()
df4['a_shift'] = df4['a'].shift(1)  # a, a_diff값의 차이
df4['a_minus'] = df4['a'] - df4['a_shift']   # 차분값
df4[['a', 'a_diff', 'a_shift', 'a_minus']].head()
# Out:
#           a    a_diff   a_shift   a_minus
# 0  0.474032       NaN       NaN       NaN
# 1  2.409133  1.935101  0.474032  1.935101
# 2 -0.497507 -2.906640  2.409133 -2.906640
# 3  1.848292  2.345799 -0.497507  2.345799
# 4  0.188772 -1.659520  1.848292 -1.659520

# %%
df4[['a', 'b', 'c']].diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f9cfa20>,
# ...
#       dtype=object)

# %%
df4[['a', 'b', 'c']].diff().hist(color='k', alpha=0.5, bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fc19da0>,
# ...
#       dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))  # hist를 그림
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120104358>,
# ...
#       dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data = pd.DataFrame({'a' : np.random.randn(1000), 
                    'b' : np.random.randint(0, 4, 1000)})

data.head()
# Out:
#           a  b
# 0 -0.985256  1
# 1  1.019361  2
# 2 -1.011427  1
# 3  1.483163  1
# 4 -0.458535  2

# %%
data['a'].hist(by = data['b'], figsize = (6, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120231f28>,
# ...
#       dtype=object)

# %% [markdown]
# ## 21강) 파이썬 시각화 상자 수염 그림(box plot) 그리기

# %% [markdown]
# ## box plot
#
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# * box-and-whisker plot, box-and-whisker diagram
#
# * [상자 수염 그림 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EC%83%81%EC%9E%90_%EC%88%98%EC%97%BC_%EA%B7%B8%EB%A6%BC)
# * 가공하지 않은 자료 그대로를 이용하여 그린 것이 아니라, 자료로부터 얻어낸 통계량인 5가지 요약 수치로 그린다.
# * 5가지 요약 수치란 기술통계학에서 자료의 정보를 알려주는 아래의 다섯 가지 수치를 의미한다.
#
#
# 1. 최솟값
# 1. 제 1사분위수
# 1. 제 2사분위수( ), 즉 중앙값
# 1. 제 3 사분위 수( )
# 1. 최댓값

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.459087  0.700371  0.676416  0.751533  0.668326
# 1  0.150823  0.228871  0.862624  0.407007  0.574272
# 2  0.681150  0.402082  0.862948  0.400108  0.381472
# 3  0.303930  0.167771  0.023407  0.460459  0.850467
# 4  0.453062  0.150157  0.528210  0.365529  0.025619
# 5  0.314514  0.952101  0.209417  0.010698  0.567963
# 6  0.839120  0.285258  0.358008  0.341033  0.402830
# 7  0.215595  0.405771  0.119511  0.888926  0.759107
# 8  0.544580  0.477714  0.404389  0.429070  0.407004
# 9  0.655185  0.452764  0.117192  0.163618  0.450764

# %%
# 데이터의 요약된 수치를 보기
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.461704   0.422286   0.416212   0.421798   0.508782
# std     0.220796   0.248939   0.308606   0.252657   0.232680
# min     0.150823   0.150157   0.023407   0.010698   0.025619
# 25%     0.306576   0.242968   0.141987   0.347157   0.403873
# 50%     0.456074   0.403926   0.381198   0.403558   0.509363
# 75%     0.627534   0.471477   0.639365   0.452612   0.644812
# max     0.839120   0.952101   0.862948   0.888926   0.850467

# %%
df.plot.box()

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange',
         'medians': 'DarkBlue', 'caps': 'Gray'}

# %%
# sym = 'r+'를 통해 이상치는 red의 + 형태로 표시하도록. 
# color는 위에서 지정한대로. boxes는 darkgreen, whiskers는 darkorange, medians는 darkblue, caps는 gray
df.plot.box(color = color, sym = 'r+')

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10, 5))
df
# Out:
#           0         1         2         3         4
# 0  0.254667  0.704861  0.183361  0.919914  0.969694
# 1  0.339155  0.399583  0.752573  0.515042  0.121151
# 2  0.585357  0.035438  0.796855  0.405480  0.901343
# 3  0.321173  0.818437  0.543584  0.922270  0.748264
# 4  0.051733  0.876150  0.731966  0.276919  0.343750
# 5  0.772044  0.581937  0.528277  0.430004  0.606570
# 6  0.641167  0.824584  0.489862  0.708654  0.647935
# 7  0.688152  0.980938  0.035460  0.246476  0.060231
# 8  0.816394  0.392266  0.380805  0.915383  0.804199
# 9  0.728352  0.312127  0.424237  0.208197  0.297769

# %%
bp = df.boxplot() # grid를 그려주게 됨

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])
df
# Out:
#        Col1      Col2
# 0  0.700799  0.925795
# 1  0.359724  0.204015
# 2  0.594981  0.646055
# 3  0.308115  0.417240
# 4  0.365053  0.684690
# 5  0.537585  0.164974
# 6  0.501042  0.457061
# 7  0.817931  0.642236
# 8  0.608533  0.752737
# 9  0.945281  0.111251

# %%
# df에 'X'라는 컬럼을 하나 만들어주기
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])
df
# Out:
#        Col1      Col2  X
# 0  0.700799  0.925795  A
# 1  0.359724  0.204015  A
# 2  0.594981  0.646055  A
# 3  0.308115  0.417240  A
# 4  0.365053  0.684690  A
# 5  0.537585  0.164974  B
# 6  0.501042  0.457061  B
# 7  0.817931  0.642236  B
# 8  0.608533  0.752737  B
# 9  0.945281  0.111251  B

# %%
bp = df.boxplot(by = 'X')

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box['g'] = np.random.choice(['A', 'B'], size=50)
df_box.loc[df_box['g'] == 'B', 1] += 3
# 다른 변수에 담아 그려주면 격자 그리드를 그릴 수도 있다.
bp = df_box.groupby('g').boxplot()

# %% [markdown]
# ## 22강) 파이썬 데이터 시각화 Area plot, Grid옵션으로 그래프 격자 만들기
# ### area plot 산점도
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# - 데이터에 NaN이 들어있으면 자동으로 0으로 채워준다. 산점도를 그리기 전에 dataframe.dropna() or dataframe.fillna()를 통해 비어있는 값을 따로 처리할 수도 있지만 디폴트값은 0으로 채워준다.
# - area plot은 값을 누적하는게 기본 옵션이라 함

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195
# 5  0.889963  0.993567  0.818704  0.545122
# 6  0.451254  0.890557  0.973265  0.593411
# 7  0.366074  0.323095  0.871423  0.215634
# 8  0.734945  0.365619  0.801603  0.782736
# 9  0.701355  0.622777  0.493683  0.840538

# %%
df.plot()

# %%
# 기본적으로 stacked = True가 옵션이다. 누적해서 그린다.
df.plot.area()

# %%
df.plot.area(stacked = False)

# %%
# grid = True를 통해 격자무늬를 생성해줄 수 있다. 
df.plot(grid = True)

# %%
df.plot.area(stacked = False, grid = True)

# %% [markdown]
# ## 23강) Pandas 데이터 시각화 scatter plot, 산점도 그리기

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195
# 5  0.889963  0.993567  0.818704  0.545122
# 6  0.451254  0.890557  0.973265  0.593411
# 7  0.366074  0.323095  0.871423  0.215634
# 8  0.734945  0.365619  0.801603  0.782736
# 9  0.701355  0.622777  0.493683  0.840538

# %%
# x축에 어떤 데이터를 넣을지, y축에 어떤 데이터를 넣을지 괄호 안에 꼭 넣어주어야 한다.
df.plot.scatter(x = 'a', y = 'b', s = 50, grid = True)

# s를 통해 점의 사이즈를 정할 수 있다.
# grid = True를 통해 격자를 줄 수도 있다.

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkRed', label='Group 1', s = 50)
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax, s = 100)

# %%
# x, y옵션뿐아니라 c라는 옵션도 추가
df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
df.plot.scatter(x = 'a', y = 'b', s = df['c'] * 200)

# %% [markdown]
# ## 24강) 파이썬 데이터 시각화 히스토그램과 산점도를 보완한 Hexbin plot그리기
# ### Hexagonal Bin Plot
# * Hexbin plot은 데이터가 클 때 각각의 점을 산점도(scatter plot)로 표현할 때의 단점을 보완할 수 있습니다.
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#hexagonal-bin-plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000) # 각각의 인덱스 값들을 추가해주었다.

# %%
df.head()
# Out:
#           a         b
# 0 -0.464099  1.754898
# 1 -0.085413  0.707111
# 2 -0.184558  3.742761
# 3  1.250715  1.618758
# 4 -0.090585  3.896935

# %%
df.tail()
# Out:
#             a           b
# 995 -0.812978  994.846914
# 996 -0.885363  997.039158
# 997  0.727986  994.974051
# 998 -0.627306  997.511348
# 999  0.938477  998.679042

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df.plot.hexbin(x='a', y='b', gridsize=10)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] = df['b'] + np.arange(1000)

# 새로운 'z'컬럼을 추가
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df['z']
# Out:
# 0      1.112848
# 1      1.885882
# 2      0.726082
# 3      1.273861
# 4      1.825675
# 5      1.149159
# 6      2.183879
# 7      0.140957
# 8      0.128619
# 9      2.149928
# 10     1.890704
# 11     2.389380
# 12     2.831719
# 13     1.464159
# 14     0.291922
# 15     0.615634
# 16     1.528472
# 17     1.400720
# 18     2.292467
# 19     0.245192
# 20     0.837086
# 21     0.261046
# 22     0.539895
# 23     2.231998
# 24     0.995025
# 25     2.937952
# 26     2.692270
# 27     1.534207
# 28     1.986332
# 29     2.029970
#          ...
# 970    0.260744
# 971    0.906070
# 972    0.421636
# 973    1.603093
# 974    1.393295
# 975    2.447948
# 976    1.247779
# 977    2.397166
# 978    0.583282
# 979    2.598429
# 980    0.908897
# 981    2.939105
# 982    1.423029
# 983    1.940385
# 984    2.508287
# 985    1.522367
# 986    2.675706
# 987    0.636151
# 988    0.262181
# 989    2.072745
# 990    2.446260
# 991    1.593392
# 992    2.028581
# 993    0.026527
# ...

# %%
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)

# %% [markdown]
# ### reduce_C_function이란?
# - 기본적으로 각 (x, y)점 주변의 개수에 대한 히스토그램이 계산된다. C 및 reduce_C_function 인수에 값을 전달하여 대체 집계를 지정할 수 있다. C는 각 (x, y)점에서 값을 지정하고 reduce_C_function은 빈의 모든 값을 단일 숫자 (ex : 평균, 최대값, 합계, 표준)로 줄이는 하나의 인수의 함수이다. 이 예에서 위치는 열(column) a 및 b에 의해 주어지며 값은 열(z)에 의해 주어진다. 빈은 NumPy의 max함수로 집계된다.

# %% [markdown]
# ## 25강) Pandas pie, plot, 원그래프, 왜 seaborn에는 파이차트가 없을까?

# %% [markdown]
# ## 26강) Scatter Matrix Plot 산점도와 커널밀도함수를 함께 표현해보자

# %% [markdown]
# ## 27강) 파이썬 시각화 분포도 그리기, Kernel Density Estimate plot 커널밀도함수, 밀도함수
